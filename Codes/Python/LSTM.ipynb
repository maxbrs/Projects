# %% [markdown]
# # LSTM tutorial

# %% [markdown]
# https://machinelearningmastery.com/timedistributed-layer-for-long-short-term-memory-networks-in-python/

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### One-to-One LSTM for Sequence Prediction

# %%
x_train = np.arange(0, 100)
x_train.reshape(1,len(x_train),1) #1 sample, 100 time steps, and 1 feature
y_train = np.arange(1, 101)
y_train.reshape(1,len(y_train),1) #1 sample, 100 time steps, and 1 feature

x_train = np.arange(100, 200)
y_train = np.arange(101, 201)

# %%
# define LSTM configuration
n_neurons = length
n_batch = length
n_epoch = 5000

# %%
# create LSTM
model = Sequential()
model.add(LSTM(n_neurons, input_shape=(1, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 5)                 140
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# ...
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
inputs = 1
outputs = 5
n = ( 4 * ((inputs + 1) * outputs + outputs**2) )
print('Number of parameters for the first layer : ' + str(n))

inputs = 5
outputs = 1
n = inputs * outputs + outputs
print('Number of parameters for the final layer : ' + str(n))
# Out:
# Number of parameters for the first layer : 140
# Number of parameters for the final layer : 6

# %%
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2)
# Out:
# Epoch 1/1000
# 0s - loss: 1.6925e-04
# Epoch 2/1000
# 0s - loss: 1.6906e-04
# Epoch 3/1000
# 0s - loss: 1.6887e-04
# Epoch 4/1000
# 0s - loss: 1.6868e-04
# Epoch 5/1000
# 0s - loss: 1.6849e-04
# Epoch 6/1000
# 0s - loss: 1.6830e-04
# Epoch 7/1000
# 0s - loss: 1.6812e-04
# Epoch 8/1000
# 0s - loss: 1.6793e-04
# Epoch 9/1000
# 0s - loss: 1.6775e-04
# Epoch 10/1000
# 0s - loss: 1.6757e-04
# Epoch 11/1000
# 0s - loss: 1.6739e-04
# Epoch 12/1000
# 0s - loss: 1.6722e-04
# Epoch 13/1000
# 0s - loss: 1.6704e-04
# Epoch 14/1000
# 0s - loss: 1.6687e-04
# Epoch 15/1000
# 0s - loss: 1.6669e-04
# Epoch 16/1000
# 0s - loss: 1.6652e-04
# Epoch 17/1000
# 0s - loss: 1.6635e-04
# Epoch 18/1000
# 0s - loss: 1.6618e-04
# Epoch 19/1000
# 0s - loss: 1.6601e-04
# Epoch 20/1000
# 0s - loss: 1.6585e-04
# Epoch 21/1000
# 0s - loss: 1.6568e-04
# Epoch 22/1000
# 0s - loss: 1.6551e-04
# Epoch 23/1000
# 0s - loss: 1.6535e-04
# Epoch 24/1000
# 0s - loss: 1.6519e-04
# Epoch 25/1000
# 0s - loss: 1.6503e-04
# ...

# %%
# evaluate
result = model.predict(X, batch_size=n_batch, verbose=0)
for value in result:
    print('%.1f' % value)
# Out:
# 0.0
# 0.2
# 0.4
# 0.6
# 0.8

# %% [markdown]
# ### Many-to-One LSTM for Sequence Prediction

# %%
X = seq.reshape(1, 5, 1)
y = seq.reshape(1, 5)
